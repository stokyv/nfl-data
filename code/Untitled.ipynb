# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## STOPPED AT
# https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html#The-apply()-method

# %% [markdown]
# ## Python & numpy tutorial

# %%
#string concat
# how do we concatenate strings in python?
# using +
hw = 'ehhlo' + ' ' + 'world'
print(hw)
#string formatting
print(' {}{}{}'.format('hello', 'viet', '!'))
#string methods
#capitalize
# upper, rjust, center, replace(this withat that), strip


#container
#list:
#how to remove and return the last elem of the list
# append, extend, indexing
# slicing access sublists
#llop over list
#access index + elem in a list
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print('#{}: {}'.format(idx + 1, animal))
    
list comprehension
#whats the equiv way of writing this
nums = [0, 1, 2, 3, 4]
squares = [x ** 2 for x in nums]
squares = []
for x in nums:
    squares.append(x ** 2)
print(squares)
even_squares = [x ** 2 for x in nums if x % 2 == 0]
print(even_squares)

#dictionaries #stores key-val pairs
d = {'cat': 'cute', 'dog': 'furry'}
#return the value of a key
d['cat']
#check if dic has key
'cat' in d
#set value for key
d['cat'] = 'ugly'
#KeyErro: key not in dic
# d['monkey']
#get key, specifies returned val if not present in dic
d.get('monkey', 'NA')
#delete key
d['fish']
#iterate over keys
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal, legs in d.items():
    print('A {} has {} legs'.format(animal, legs))
    
#dictionary comprehensions
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)

#sets: unordered collection of ditinct elems
animals = {'cat', 'dog'}
print('cat' in animals)   # Check if an element is in a set; prints "True"
print('fish' in animals)
#add new item
animals.add('fish')      # Add an element to a set
print('fish' in animals)
print(len(animals))  
#remove item from a set
#loop
animals = {'cat', 'dog', 'fish'}
for idx, animal in enumerate(animals):
    print('#{}: {}'.format(idx + 1, animal))
#set comprehension
from math import sqrt
print({int(sqrt(x)) for x in range(30)})



#tuple: immutable ordered list of vals
#functions
#

#classes
#constructor
#instance method

#NUMPY
import numpy as np
#create an array of 1 2 3
#view its type, shape, access 1st elem
#create rank 2 array 1 2 3, 4 5 6
#acess elem at [0,0] [0,1]
#creat arr of zeros with this shape
#creat arr of 1s with this shape
#creat constant arr of this shape of this value
# create an N-identity matrix
#Create an array filled with random values

#Array indexing
#multidimensional slicing
#slicice 1st two rows, cols 1 and 2
b[:2, 1:3]
# is a slice a view or a copy?
### a view -> changing a slicice means changing the original data
#mixing integer indexing with slicing: rank of result vs rank of original?
###rank of result < rank of orig arr

#integer array indexing: create arbitrary arrs using data from anotehr
a = np.array([[1,2], [3, 4], [5, 6]])

# An example of integer array indexing.
# The returned array will have shape (3,) and 
print(a[[0, 1, 2], [0, 1, 0]])

#use integer array indexing to select an item from ea row
# Create an array of indices
b = np.array([0, 2, 0, 1])

# Select one element from each row of a using the indices in b
print(a[np.arange(4), b])  # Prints "[ 1  6  7 11]"
#mutate thsee elems is fine too
# Mutate one element from each row of a using the indices in b
a[np.arange(4), b] += 10
print(a)

#boolean array indexing
#what is the rank of the returning array
### 1
a = np.array([[1,2], [3, 4], [5, 6]])

bool_idx = (a > 2)
print(a[bool_idx])
print(a[a > 2])

#dtype: int64, float64
a.dtype

#array math
#elemwist sum, differenct, product, division,sqrt
### add, subtract, multiply, divide sqareroot

#matrix multiplication
# v.dot(w)
# np.dot(v, w)
# v@w

#sum of all elems
#sum of ea col
#sum of ea row


#transpose
# x.T

#broadcasting
#explicitfor loop, row-adding
#?tile: stack arr X into a 4x1 pile 
np.tile(X,(4,1))
#reshape w to be a row vector of shape 2x1
np.reshape(w, (2, 1))

#plot
#np.arange()

import numpy as np

np.arange(0, 10, 3) #start-inclusive, end-exclusive,
